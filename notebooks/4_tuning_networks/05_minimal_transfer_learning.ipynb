# %% [markdown]
# <td>
# <a href="https://colab.research.google.com/github/raoulg/MADS-MachineLearning-course/blob/master/notebooks/4_tuning_networks/05_minimal_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td>

# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# This tutorial is based on the PyTorch tutorial for transfer learning. The original tutorial can be found [here](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).
#
# Transfer learning utilizes the idea that a model trained on a large dataset can be used as a starting point for a model trained on a smaller dataset. This is especially useful when the smaller dataset is not large enough to train a model from scratch. In this tutorial, we will use a pre-trained model to classify ants and bees. The dataset contains 120 training images and 75 validation images for each class.
#
# The two major transfer learning scenarios look as follows:
#
# -   **Finetuning the ConvNet**: Instead of random initialization, we
#     initialize the network with a pretrained network, like the one that
#     is trained on imagenet 1000 dataset. Rest of the training looks as
#     usual.
# -   **ConvNet as fixed feature extractor**: Here, we will freeze the
#     weights for all of the network except that of the final fully
#     connected layer. This last fully connected layer is replaced with a
#     new one with random weights and only this layer is trained.

# %%
import os

# Check if the notebook is running on Google Colab
if 'COLAB_GPU' in os.environ:
    # Running on Google Colab; install loguru
    # !pip install loguru
else:
    # Not running on Google Colab; you might be on a local setup
    print("Not running on Google Colab. Make sure you have hardware accelaration available.")

from pathlib import Path
import requests
import zipfile
from loguru import logger
# Out:
# Not running on Google Colab. Make sure you have hardware accelaration available.

# %% [markdown]
# Let's download a small dataset.

# %%
def get_hymenoptera():
    datadir = Path.home() / ".cache/mads_datasets/hymenoptera_data"
    url = "https://download.pytorch.org/tutorial/hymenoptera_data.zip"
    if not datadir.exists():
        logger.info(f"Creating directory {datadir}")
        datadir.mkdir(parents=True)

        response = requests.get(url)
        zip_file_path = datadir / "hymenoptera_data.zip"
        with open(zip_file_path, "wb") as f:
            f.write(response.content)

        logger.info(f"Extracting {zip_file_path}")
        with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
            zip_ref.extractall(datadir)
        zip_file_path.unlink()
    else:
        logger.info(f"Directory {datadir} already exists, skipping download.")
    return datadir / "hymenoptera_data"

datadir = get_hymenoptera()
# Out:
# 2024-10-04 23:16:24.527 | INFO     | __main__:get_hymenoptera:5 - Creating directory /home/wchau/.cache/mads_datasets/hymenoptera_data
# 2024-10-04 23:16:24.760 | INFO     | __main__:get_hymenoptera:13 - Extracting /home/wchau/.cache/mads_datasets/hymenoptera_data/hymenoptera_data.zip

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# Load Data
# =========
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we\'re going to solve is training a model to classify
# **ants** and **bees**. We have about 120 training images each for ants
# and bees.
#
# There are 75 validation images for each class. Usually, this
# is too small of a dataset to generalize upon, if trained from scratch.
# Since we are using transfer learning, we should be able to generalize
# reasonably well.
#
# This dataset is a very small subset of imagenet.

# %%
def create_dataloaders():
    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'val': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }

    image_datasets = {x: datasets.ImageFolder(datadir / x, data_transforms[x]) for x in ['train', 'val']}
    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                                shuffle=True, num_workers=4)
                for x in ['train', 'val']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
    class_names = image_datasets['train'].classes
    return dataloaders, dataset_sizes, class_names

dataloaders, dataset_sizes, class_names = create_dataloaders()

# %%
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = "cpu"
    logger.warning("This model will take 15-20 minutes on CPU. Consider using accelaration, eg with google colab (see button on top of the page)")
logger.info(f"Using {device}")
# Out:
# 2024-10-04 23:16:57.945 | INFO     | __main__:<module>:8 - Using cuda

# %% [markdown]
# Visualize a few images
# ======================
#
# Let\'s visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(img, title):
    img = img.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = std * img + mean
    img = np.clip(img, 0, 1)
    plt.imshow(img)
    plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
img = torchvision.utils.make_grid(inputs)

imshow(img, title=[class_names[x] for x in classes])

# %% [markdown]
# # Training the model

# %% [markdown]
# Up to this point, we have been using the mltrainer module.
# However, to both make it easer to run this on google colab and to show you the full code of a training loop, I will define the functions for training and evaluating the model here.

# %%
def train(model, dataloader, lossfn, optimizer, device):
    model.train()
    train_loss: float = 0.0
    train_acc: float = 0.0
    for x, y in dataloader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        yhat = model(x)
        loss = lossfn(yhat, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, acc = torch.max(yhat, 1)
        train_acc += torch.sum(acc == y.data)
    return train_loss, train_acc

# %%
def test(model, dataloader, lossfn, optimizer, scheduler, device):
    model.eval()
    test_loss: float = 0.0
    test_acc: float = 0.0
    for x, y in dataloader:
        x = x.to(device)
        y = y.to(device)
        yhat = model(x)
        loss = lossfn(yhat, y)
        test_loss += loss.item()
        _, acc = torch.max(yhat, 1)
        test_acc += torch.sum(acc == y.data)
    scheduler.step(test_loss)
    return test_loss, test_acc

# %%
def train_model(model, lossfn, optimizer, scheduler, num_epochs, dataloaders, dataset_sizes, device):
    with TemporaryDirectory() as tempdir:
        best_model_params_path = Path(tempdir) / 'best_model_params.pt'
        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0 # we will only save the best model

        for epoch in range(num_epochs):
            logger.info(f'Epoch {epoch}/{num_epochs - 1}')
            train_loss, train_acc = train(model, dataloaders['train'], lossfn, optimizer, device)
            train_loss = train_loss / dataset_sizes['train']
            train_acc = train_acc / dataset_sizes['train']
            logger.info(f'Train Loss: {train_loss:.4f} Accuracy: {train_acc:.4f}')
            test_loss, test_acc = test(model, dataloaders['val'], lossfn, optimizer, scheduler, device)
            test_loss = test_loss / dataset_sizes['val']
            test_acc = test_acc / dataset_sizes['val']
            logger.info(f'Test Loss: {test_loss:.4f} Accuracy: {test_acc:.4f}')
            if test_acc > best_acc:
                    best_acc = test_acc
                    logger.info(f"New best accuracy: {best_acc:.4f}, saving model")
                    torch.save(model.state_dict(), best_model_params_path)
        model.load_state_dict(torch.load(best_model_params_path))
        return model

# %% [markdown]
# Visualizing the model predictions
# =================================
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                title = class_names[preds[j]]
                ax.set_title(f'predicted: {title}')
                imshow(inputs.cpu().data[j], title)

                if images_so_far == num_images:
                    return

# %% [markdown]
# Finetuning the ConvNet
# ======================
#
# Load a pretrained model and reset final fully connected layer.

# %%
model = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 2)

model = model.to(device)
lossfn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs

settings = {'step_size' : 7, 'gamma' : 0.1}
scheduler = lr_scheduler.StepLR(optimizer, **settings)

# %%
model = train_model(model, lossfn, optimizer, scheduler, 25, dataloaders, dataset_sizes, device)
# Out:
# 2024-10-04 23:17:39.177 | INFO     | __main__:train_model:8 - Epoch 0/24
# 2024-10-04 23:17:42.158 | INFO     | __main__:train_model:12 - Train Loss: 0.1725 Accuracy: 0.7090
# /home/wchau/MADS-MachineLearning-course-forked/.venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 2024-10-04 23:17:42.732 | INFO     | __main__:train_model:16 - Test Loss: 0.0854 Accuracy: 0.8889
# 2024-10-04 23:17:42.753 | INFO     | __main__:train_model:19 - New best accuracy: 0.8889, saving model
# 2024-10-04 23:17:42.894 | INFO     | __main__:train_model:8 - Epoch 1/24
# 2024-10-04 23:17:43.828 | INFO     | __main__:train_model:12 - Train Loss: 0.0813 Accuracy: 0.8689
# 2024-10-04 23:17:44.251 | INFO     | __main__:train_model:16 - Test Loss: 0.0581 Accuracy: 0.8954
# 2024-10-04 23:17:44.253 | INFO     | __main__:train_model:19 - New best accuracy: 0.8954, saving model
# 2024-10-04 23:17:44.383 | INFO     | __main__:train_model:8 - Epoch 2/24
# 2024-10-04 23:17:45.271 | INFO     | __main__:train_model:12 - Train Loss: 0.1013 Accuracy: 0.8361
# 2024-10-04 23:17:45.732 | INFO     | __main__:train_model:16 - Test Loss: 0.0609 Accuracy: 0.9085
# 2024-10-04 23:17:45.733 | INFO     | __main__:train_model:19 - New best accuracy: 0.9085, saving model
# 2024-10-04 23:17:45.875 | INFO     | __main__:train_model:8 - Epoch 3/24
# 2024-10-04 23:17:46.805 | INFO     | __main__:train_model:12 - Train Loss: 0.0895 Accuracy: 0.8197
# 2024-10-04 23:17:47.235 | INFO     | __main__:train_model:16 - Test Loss: 0.0498 Accuracy: 0.9216
# 2024-10-04 23:17:47.236 | INFO     | __main__:train_model:19 - New best accuracy: 0.9216, saving model
# 2024-10-04 23:17:47.366 | INFO     | __main__:train_model:8 - Epoch 4/24
# 2024-10-04 23:17:48.219 | INFO     | __main__:train_model:12 - Train Loss: 0.0915 Accuracy: 0.8525
# 2024-10-04 23:17:48.748 | INFO     | __main__:train_model:16 - Test Loss: 0.0479 Accuracy: 0.9216
# 2024-10-04 23:17:48.750 | INFO     | __main__:train_model:8 - Epoch 5/24
# 2024-10-04 23:17:49.631 | INFO     | __main__:train_model:12 - Train Loss: 0.0967 Accuracy: 0.8361
# 2024-10-04 23:17:50.079 | INFO     | __main__:train_model:16 - Test Loss: 0.0478 Accuracy: 0.9346
# 2024-10-04 23:17:50.081 | INFO     | __main__:train_model:19 - New best accuracy: 0.9346, saving model
# 2024-10-04 23:17:50.206 | INFO     | __main__:train_model:8 - Epoch 6/24
# 2024-10-04 23:17:51.106 | INFO     | __main__:train_model:12 - Train Loss: 0.0825 Accuracy: 0.8484
# 2024-10-04 23:17:51.567 | INFO     | __main__:train_model:16 - Test Loss: 0.0464 Accuracy: 0.9346
# 2024-10-04 23:17:51.568 | INFO     | __main__:train_model:8 - Epoch 7/24
# 2024-10-04 23:17:52.438 | INFO     | __main__:train_model:12 - Train Loss: 0.0907 Accuracy: 0.8443
# 2024-10-04 23:17:52.871 | INFO     | __main__:train_model:16 - Test Loss: 0.0491 Accuracy: 0.9281
# 2024-10-04 23:17:52.873 | INFO     | __main__:train_model:8 - Epoch 8/24
# 2024-10-04 23:17:53.732 | INFO     | __main__:train_model:12 - Train Loss: 0.0786 Accuracy: 0.8484
# 2024-10-04 23:17:54.233 | INFO     | __main__:train_model:16 - Test Loss: 0.0470 Accuracy: 0.9346
# 2024-10-04 23:17:54.235 | INFO     | __main__:train_model:8 - Epoch 9/24
# 2024-10-04 23:17:55.101 | INFO     | __main__:train_model:12 - Train Loss: 0.0791 Accuracy: 0.8689
# 2024-10-04 23:17:55.578 | INFO     | __main__:train_model:16 - Test Loss: 0.0469 Accuracy: 0.9412
# 2024-10-04 23:17:55.580 | INFO     | __main__:train_model:19 - New best accuracy: 0.9412, saving model
# 2024-10-04 23:17:55.788 | INFO     | __main__:train_model:8 - Epoch 10/24
# 2024-10-04 23:17:56.649 | INFO     | __main__:train_model:12 - Train Loss: 0.0833 Accuracy: 0.8361
# 2024-10-04 23:17:57.064 | INFO     | __main__:train_model:16 - Test Loss: 0.0455 Accuracy: 0.9412
# 2024-10-04 23:17:57.066 | INFO     | __main__:train_model:8 - Epoch 11/24
# 2024-10-04 23:17:57.957 | INFO     | __main__:train_model:12 - Train Loss: 0.1302 Accuracy: 0.7869
# 2024-10-04 23:17:58.408 | INFO     | __main__:train_model:16 - Test Loss: 0.0559 Accuracy: 0.9085
# 2024-10-04 23:17:58.410 | INFO     | __main__:train_model:8 - Epoch 12/24
# 2024-10-04 23:17:59.328 | INFO     | __main__:train_model:12 - Train Loss: 0.1010 Accuracy: 0.8402
# 2024-10-04 23:17:59.777 | INFO     | __main__:train_model:16 - Test Loss: 0.0372 Accuracy: 0.9542
# 2024-10-04 23:17:59.779 | INFO     | __main__:train_model:19 - New best accuracy: 0.9542, saving model
# 2024-10-04 23:17:59.925 | INFO     | __main__:train_model:8 - Epoch 13/24
# 2024-10-04 23:18:00.781 | INFO     | __main__:train_model:12 - Train Loss: 0.1375 Accuracy: 0.7910
# 2024-10-04 23:18:01.202 | INFO     | __main__:train_model:16 - Test Loss: 0.0912 Accuracy: 0.9020
# 2024-10-04 23:18:01.204 | INFO     | __main__:train_model:8 - Epoch 14/24
# 2024-10-04 23:18:02.108 | INFO     | __main__:train_model:12 - Train Loss: 0.1009 Accuracy: 0.8852
# 2024-10-04 23:18:02.532 | INFO     | __main__:train_model:16 - Test Loss: 0.0512 Accuracy: 0.9346
# 2024-10-04 23:18:02.533 | INFO     | __main__:train_model:8 - Epoch 15/24
# 2024-10-04 23:18:03.482 | INFO     | __main__:train_model:12 - Train Loss: 0.0950 Accuracy: 0.8443
# 2024-10-04 23:18:04.021 | INFO     | __main__:train_model:16 - Test Loss: 0.0497 Accuracy: 0.9477
# 2024-10-04 23:18:04.022 | INFO     | __main__:train_model:8 - Epoch 16/24
# 2024-10-04 23:18:05.049 | INFO     | __main__:train_model:12 - Train Loss: 0.0956 Accuracy: 0.8402
# 2024-10-04 23:18:05.584 | INFO     | __main__:train_model:16 - Test Loss: 0.0487 Accuracy: 0.9412
# 2024-10-04 23:18:05.586 | INFO     | __main__:train_model:8 - Epoch 17/24
# 2024-10-04 23:18:06.702 | INFO     | __main__:train_model:12 - Train Loss: 0.1077 Accuracy: 0.8402
# 2024-10-04 23:18:07.277 | INFO     | __main__:train_model:16 - Test Loss: 0.0589 Accuracy: 0.9150
# 2024-10-04 23:18:07.278 | INFO     | __main__:train_model:8 - Epoch 18/24
# 2024-10-04 23:18:08.326 | INFO     | __main__:train_model:12 - Train Loss: 0.0763 Accuracy: 0.8607
# 2024-10-04 23:18:08.855 | INFO     | __main__:train_model:16 - Test Loss: 0.0414 Accuracy: 0.9542
# 2024-10-04 23:18:08.856 | INFO     | __main__:train_model:8 - Epoch 19/24
# 2024-10-04 23:18:09.909 | INFO     | __main__:train_model:12 - Train Loss: 0.1188 Accuracy: 0.8279
# 2024-10-04 23:18:10.473 | INFO     | __main__:train_model:16 - Test Loss: 0.0808 Accuracy: 0.8693
# 2024-10-04 23:18:10.475 | INFO     | __main__:train_model:8 - Epoch 20/24
# 2024-10-04 23:18:11.518 | INFO     | __main__:train_model:12 - Train Loss: 0.0896 Accuracy: 0.8648
# 2024-10-04 23:18:12.141 | INFO     | __main__:train_model:16 - Test Loss: 0.0662 Accuracy: 0.9085
# 2024-10-04 23:18:12.144 | INFO     | __main__:train_model:8 - Epoch 21/24
# 2024-10-04 23:18:13.182 | INFO     | __main__:train_model:12 - Train Loss: 0.0566 Accuracy: 0.8975
# 2024-10-04 23:18:13.691 | INFO     | __main__:train_model:16 - Test Loss: 0.0591 Accuracy: 0.9020
# 2024-10-04 23:18:13.693 | INFO     | __main__:train_model:8 - Epoch 22/24
# 2024-10-04 23:18:14.789 | INFO     | __main__:train_model:12 - Train Loss: 0.0798 Accuracy: 0.8648
# 2024-10-04 23:18:15.257 | INFO     | __main__:train_model:16 - Test Loss: 0.0539 Accuracy: 0.9216
# 2024-10-04 23:18:15.259 | INFO     | __main__:train_model:8 - Epoch 23/24
# 2024-10-04 23:18:16.199 | INFO     | __main__:train_model:12 - Train Loss: 0.0831 Accuracy: 0.8443
# 2024-10-04 23:18:16.656 | INFO     | __main__:train_model:16 - Test Loss: 0.0467 Accuracy: 0.9281
# 2024-10-04 23:18:16.658 | INFO     | __main__:train_model:8 - Epoch 24/24
# 2024-10-04 23:18:17.641 | INFO     | __main__:train_model:12 - Train Loss: 0.0678 Accuracy: 0.8811
# 2024-10-04 23:18:18.129 | INFO     | __main__:train_model:16 - Test Loss: 0.0481 Accuracy: 0.9412

# %% [markdown]
# Train and evaluate
# ==================
#
# It should take around 15-25 min on CPU. On GPU though, it takes less
# than a minute.

# %%
visualize_model(model)

# %% [markdown]
# ConvNet as fixed feature extractor
# ==================================
#
# Here, we need to freeze all the network except the final layer. We need
# to set `requires_grad = False` to freeze the parameters so that the
# gradients are not computed in `backward()`.
#
# This has some advantages over finetuning the complete model:
# - **Faster**: Since we are not computing most of the gradients, the
#     forward pass is faster.
# - **Memory Efficient**: The memory required for computing the gradients is
#     less.
# - **Less risk of overfitting**: Since most of the model is frozen, the
#     risk of overfitting on this small dataset is less.

# %%
model_conv = torchvision.models.resnet18(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

lossfn = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %% [markdown]
# Train and evaluate
# ==================
#
# On CPU this will take about half the time compared to previous scenario.
# This is expected as gradients don\'t need to be computed for most of the
# network. However, forward does need to be computed.

# %%
model_conv = train_model(model_conv, lossfn, optimizer, scheduler, 25, dataloaders, dataset_sizes, device)
# Out:
# 2024-10-04 23:18:55.270 | INFO     | __main__:train_model:8 - Epoch 0/24
# 2024-10-04 23:18:55.844 | INFO     | __main__:train_model:12 - Train Loss: 0.2032 Accuracy: 0.5656
# 2024-10-04 23:18:56.319 | INFO     | __main__:train_model:16 - Test Loss: 0.1376 Accuracy: 0.6993
# 2024-10-04 23:18:56.320 | INFO     | __main__:train_model:19 - New best accuracy: 0.6993, saving model
# 2024-10-04 23:18:56.449 | INFO     | __main__:train_model:8 - Epoch 1/24
# 2024-10-04 23:18:57.038 | INFO     | __main__:train_model:12 - Train Loss: 0.2259 Accuracy: 0.5779
# 2024-10-04 23:18:57.498 | INFO     | __main__:train_model:16 - Test Loss: 0.1300 Accuracy: 0.7386
# 2024-10-04 23:18:57.500 | INFO     | __main__:train_model:19 - New best accuracy: 0.7386, saving model
# 2024-10-04 23:18:57.670 | INFO     | __main__:train_model:8 - Epoch 2/24
# 2024-10-04 23:18:58.264 | INFO     | __main__:train_model:12 - Train Loss: 0.1740 Accuracy: 0.6639
# 2024-10-04 23:18:58.697 | INFO     | __main__:train_model:16 - Test Loss: 0.0684 Accuracy: 0.8889
# 2024-10-04 23:18:58.699 | INFO     | __main__:train_model:19 - New best accuracy: 0.8889, saving model
# 2024-10-04 23:18:58.828 | INFO     | __main__:train_model:8 - Epoch 3/24
# 2024-10-04 23:18:59.397 | INFO     | __main__:train_model:12 - Train Loss: 0.1070 Accuracy: 0.8279
# 2024-10-04 23:18:59.850 | INFO     | __main__:train_model:16 - Test Loss: 0.0490 Accuracy: 0.9346
# 2024-10-04 23:18:59.851 | INFO     | __main__:train_model:19 - New best accuracy: 0.9346, saving model
# 2024-10-04 23:18:59.973 | INFO     | __main__:train_model:8 - Epoch 4/24
# 2024-10-04 23:19:00.574 | INFO     | __main__:train_model:12 - Train Loss: 0.0979 Accuracy: 0.8361
# 2024-10-04 23:19:01.040 | INFO     | __main__:train_model:16 - Test Loss: 0.0504 Accuracy: 0.9281
# 2024-10-04 23:19:01.042 | INFO     | __main__:train_model:8 - Epoch 5/24
# 2024-10-04 23:19:01.728 | INFO     | __main__:train_model:12 - Train Loss: 0.0944 Accuracy: 0.8320
# 2024-10-04 23:19:02.179 | INFO     | __main__:train_model:16 - Test Loss: 0.0534 Accuracy: 0.9346
# 2024-10-04 23:19:02.181 | INFO     | __main__:train_model:8 - Epoch 6/24
# 2024-10-04 23:19:02.923 | INFO     | __main__:train_model:12 - Train Loss: 0.0960 Accuracy: 0.8238
# 2024-10-04 23:19:03.460 | INFO     | __main__:train_model:16 - Test Loss: 0.0524 Accuracy: 0.9281
# 2024-10-04 23:19:03.461 | INFO     | __main__:train_model:8 - Epoch 7/24
# 2024-10-04 23:19:04.264 | INFO     | __main__:train_model:12 - Train Loss: 0.0888 Accuracy: 0.8361
# 2024-10-04 23:19:04.811 | INFO     | __main__:train_model:16 - Test Loss: 0.0487 Accuracy: 0.9346
# 2024-10-04 23:19:04.812 | INFO     | __main__:train_model:8 - Epoch 8/24
# 2024-10-04 23:19:05.597 | INFO     | __main__:train_model:12 - Train Loss: 0.0900 Accuracy: 0.8279
# 2024-10-04 23:19:06.191 | INFO     | __main__:train_model:16 - Test Loss: 0.0492 Accuracy: 0.9346
# 2024-10-04 23:19:06.193 | INFO     | __main__:train_model:8 - Epoch 9/24
# 2024-10-04 23:19:06.938 | INFO     | __main__:train_model:12 - Train Loss: 0.0832 Accuracy: 0.8484
# 2024-10-04 23:19:07.466 | INFO     | __main__:train_model:16 - Test Loss: 0.0498 Accuracy: 0.9281
# 2024-10-04 23:19:07.468 | INFO     | __main__:train_model:8 - Epoch 10/24
# 2024-10-04 23:19:08.230 | INFO     | __main__:train_model:12 - Train Loss: 0.0768 Accuracy: 0.8893
# 2024-10-04 23:19:08.748 | INFO     | __main__:train_model:16 - Test Loss: 0.0458 Accuracy: 0.9412
# 2024-10-04 23:19:08.749 | INFO     | __main__:train_model:19 - New best accuracy: 0.9412, saving model
# 2024-10-04 23:19:08.879 | INFO     | __main__:train_model:8 - Epoch 11/24
# 2024-10-04 23:19:09.603 | INFO     | __main__:train_model:12 - Train Loss: 0.0831 Accuracy: 0.8607
# 2024-10-04 23:19:10.183 | INFO     | __main__:train_model:16 - Test Loss: 0.0517 Accuracy: 0.9412
# 2024-10-04 23:19:10.184 | INFO     | __main__:train_model:8 - Epoch 12/24
# 2024-10-04 23:19:10.927 | INFO     | __main__:train_model:12 - Train Loss: 0.0848 Accuracy: 0.8443
# 2024-10-04 23:19:11.473 | INFO     | __main__:train_model:16 - Test Loss: 0.0503 Accuracy: 0.9346
# 2024-10-04 23:19:11.474 | INFO     | __main__:train_model:8 - Epoch 13/24
# 2024-10-04 23:19:12.150 | INFO     | __main__:train_model:12 - Train Loss: 0.0835 Accuracy: 0.8770
# 2024-10-04 23:19:12.761 | INFO     | __main__:train_model:16 - Test Loss: 0.0482 Accuracy: 0.9346
# 2024-10-04 23:19:12.763 | INFO     | __main__:train_model:8 - Epoch 14/24
# 2024-10-04 23:19:13.515 | INFO     | __main__:train_model:12 - Train Loss: 0.1009 Accuracy: 0.7787
# 2024-10-04 23:19:14.084 | INFO     | __main__:train_model:16 - Test Loss: 0.0503 Accuracy: 0.9412
# 2024-10-04 23:19:14.086 | INFO     | __main__:train_model:8 - Epoch 15/24
# 2024-10-04 23:19:14.815 | INFO     | __main__:train_model:12 - Train Loss: 0.0897 Accuracy: 0.8566
# 2024-10-04 23:19:15.322 | INFO     | __main__:train_model:16 - Test Loss: 0.0456 Accuracy: 0.9412
# 2024-10-04 23:19:15.324 | INFO     | __main__:train_model:8 - Epoch 16/24
# 2024-10-04 23:19:16.058 | INFO     | __main__:train_model:12 - Train Loss: 0.1244 Accuracy: 0.7623
# 2024-10-04 23:19:16.578 | INFO     | __main__:train_model:16 - Test Loss: 0.0481 Accuracy: 0.9477
# 2024-10-04 23:19:16.580 | INFO     | __main__:train_model:19 - New best accuracy: 0.9477, saving model
# 2024-10-04 23:19:16.705 | INFO     | __main__:train_model:8 - Epoch 17/24
# 2024-10-04 23:19:17.316 | INFO     | __main__:train_model:12 - Train Loss: 0.0880 Accuracy: 0.8525
# 2024-10-04 23:19:17.806 | INFO     | __main__:train_model:16 - Test Loss: 0.0466 Accuracy: 0.9346
# 2024-10-04 23:19:17.808 | INFO     | __main__:train_model:8 - Epoch 18/24
# 2024-10-04 23:19:18.466 | INFO     | __main__:train_model:12 - Train Loss: 0.0708 Accuracy: 0.8893
# 2024-10-04 23:19:18.995 | INFO     | __main__:train_model:16 - Test Loss: 0.0448 Accuracy: 0.9346
# 2024-10-04 23:19:18.997 | INFO     | __main__:train_model:8 - Epoch 19/24
# 2024-10-04 23:19:19.650 | INFO     | __main__:train_model:12 - Train Loss: 0.1292 Accuracy: 0.7623
# 2024-10-04 23:19:20.165 | INFO     | __main__:train_model:16 - Test Loss: 0.0504 Accuracy: 0.9216
# 2024-10-04 23:19:20.166 | INFO     | __main__:train_model:8 - Epoch 20/24
# 2024-10-04 23:19:20.802 | INFO     | __main__:train_model:12 - Train Loss: 0.0971 Accuracy: 0.8279
# 2024-10-04 23:19:21.290 | INFO     | __main__:train_model:16 - Test Loss: 0.0433 Accuracy: 0.9542
# 2024-10-04 23:19:21.292 | INFO     | __main__:train_model:19 - New best accuracy: 0.9542, saving model
# 2024-10-04 23:19:21.425 | INFO     | __main__:train_model:8 - Epoch 21/24
# 2024-10-04 23:19:22.005 | INFO     | __main__:train_model:12 - Train Loss: 0.1023 Accuracy: 0.7992
# 2024-10-04 23:19:22.455 | INFO     | __main__:train_model:16 - Test Loss: 0.0551 Accuracy: 0.9216
# 2024-10-04 23:19:22.457 | INFO     | __main__:train_model:8 - Epoch 22/24
# 2024-10-04 23:19:23.018 | INFO     | __main__:train_model:12 - Train Loss: 0.0683 Accuracy: 0.8893
# 2024-10-04 23:19:23.486 | INFO     | __main__:train_model:16 - Test Loss: 0.0464 Accuracy: 0.9412
# 2024-10-04 23:19:23.488 | INFO     | __main__:train_model:8 - Epoch 23/24
# 2024-10-04 23:19:24.079 | INFO     | __main__:train_model:12 - Train Loss: 0.0984 Accuracy: 0.8402
# 2024-10-04 23:19:24.522 | INFO     | __main__:train_model:16 - Test Loss: 0.0435 Accuracy: 0.9412
# 2024-10-04 23:19:24.524 | INFO     | __main__:train_model:8 - Epoch 24/24
# 2024-10-04 23:19:25.088 | INFO     | __main__:train_model:12 - Train Loss: 0.1021 Accuracy: 0.8033
# 2024-10-04 23:19:25.521 | INFO     | __main__:train_model:16 - Test Loss: 0.0420 Accuracy: 0.9477

# %%
visualize_model(model_conv)
